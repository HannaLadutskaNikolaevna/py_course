# %%
# classwork 10.08

# %%
class User:
    def __init__(self, name, phone):
        self.__name = name
        self.phone = phone

    def get_user(self):
        return self.__name

    def set_name(self, uname):
        if isinstance(uname, str):
            self.__name = uname
            return True
            return "не верное имя пользователя"

    def __repr__(self):
        return f"repr\n\tname:{self.__name}\n\tphone:{self.phone}"

    def __str__(self):
        return f"\n\tname:{self.__name}\n\tphone:{self.phone}"


dima = User("Dima", 1212421412)
    print(dima.set_name("Dimas"))
    print(dima.get_name())
    print(dima)
    print()
dima
# Out:
#   Cell In[5], line 23
#     print(dima.set_name("Dimas"))
#     ^
# IndentationError: unexpected indent

# %%
class User:
    def __init__(self, name, phone):
        self.__name = name
        self.phone = phone

    def get_name(self):
        return self.__name

    def set_name(self, uname):
        if isinstance(uname, str):
            self.__name = uname
            return True
        return "неверное имя пользователя"

    def __repr__(self):
        return f"repr\n\tname:{self.__name}\n\tphone:{self.phone}"

    def __str__(self):
        return f"\n\tname:{self.__name}\n\tphone:{self.phone}"


dima = User("Dima", 1212421412)
print(dima.set_name("Dimas"))
print(dima.get_name())  # Теперь работает корректно!
print(dima)
# Out:
# True
# Dimas
#
# 	name:Dimas
# 	phone:1212421412

# %%
class Cat:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __len__(self):
        return self.age

    def __add__(self, diff_car):
        return self.age + diff_car.age

    def __pow__(self, power):
# поддержим возведение в степень только для чисел
        return self.age ** power


vasia = Cat("Vasia", 15)
print(len(vasia))

vasia = Cat("Vasia", 15)
dima = Cat("Dima", 45)


print(vasia + dima)

print(vasia ** 3)
# Out:
# 15
# 60
# 3375

# %%
class Cat:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __len__(self):
        return self.age

    def __add__(self, diff_cat):
        return self.age + diff_cat.age

    def __pow__(self, power):
# поддержим возведение в степень только для чисел
        return self.age ** power


vasia = Cat("Vasia", 15)
print(len(vasia))

vasia = Cat("Vasia", 15)
dima = Cat("Dima", 45)


print(vasia + dima)

print(vasia ** 3)
# Out:
# 15
# 60
# 3375

# %%
class Cat:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def __len__(self):
        return self.age

    def __add__(self, diff_car):
        return self.age + diff_car.age


vasia = Cat("Vasia", 15)
print(len(vasia))

vasia = Cat("Vasia", 15)
dima = Cat("Dima", 45)


print(vasia + dima)
# Out:
# 15
# 60

# %%
class Cat:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        
    def __len__(self):
        return self.age

    def __add__(self, diff_cat):
        return self.age + diff_cat.age

    def __pow__(self, power):
        # поддержим возведение в степень только для чисел
        return self.age ** power 


vasia = Cat("Vasia", 15)
print(len(vasia))

vasia = Cat("Vasia", 15)
dima = Cat("Dima", 45)


print(vasia + dima)

print(vasia ** 3)
# Out:
# 15
# 60
# 3375

# %%
li1 = [1,2,3,4]
li2 = [1,2,3,4]
li3 = li1

# %%
print(id(li1))
print(id(li2))
print(id(li3))
# Out:
# 65824088
# 66579552
# 65824088
